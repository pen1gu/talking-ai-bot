# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\jun\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\jun\anaconda3\lib\site-packages (from konlpy) (4.6.3)
# Requirement already satisfied: colorama in c:\users\jun\anaconda3\lib\site-packages (from konlpy) (0.4.4)
# Requirement already satisfied: tweepy>=3.7.0 in c:\users\jun\anaconda3\lib\site-packages (from konlpy) (3.10.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\jun\anaconda3\lib\site-packages (from konlpy) (1.19.5)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\jun\anaconda3\lib\site-packages (from konlpy) (1.3.0)
# Requirement already satisfied: beautifulsoup4==4.6.0 in c:\users\jun\anaconda3\lib\site-packages (from konlpy) (4.6.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\jun\anaconda3\lib\site-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jun\anaconda3\lib\site-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\jun\anaconda3\lib\site-packages (from tweepy>=3.7.0->konlpy) (2.26.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jun\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jun\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jun\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jun\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jun\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\jun\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)

# %%
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# ^C
#   Running command git clone -q https://github.com/haven-jeon/PyKoSpacing.git 'C:\Users\Jun\AppData\Local\Temp\pip-req-build-q75xqrxc'
# WARNING: Error parsing requirements for h5py: [Errno 2] No such file or directory: 'c:\\users\\jun\\anaconda3\\lib\\site-packages\\h5py-2.10.0.dist-info\\METADATA'
# ERROR: Could not install packages due to an OSError: [WinError 2] 지정된 파일을 찾을 수 없습니다: 'C:\\Users\\Jun\\anaconda3\\Lib\\site-packages\\markdown\\__init__.py'
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to c:\users\jun\appdata\local\temp\pip-req-build-q75xqrxc
# Collecting tensorflow==2.5.1
#   Downloading tensorflow-2.5.1-cp38-cp38-win_amd64.whl (422.6 MB)
# Collecting h5py==3.1.0
#   Using cached h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
# Collecting argparse>=1.4.0
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy>=1.17.5 in c:\users\jun\anaconda3\lib\site-packages (from h5py==3.1.0->pykospacing==0.5) (1.19.5)
# Collecting grpcio~=1.34.0
#   Using cached grpcio-1.34.1-cp38-cp38-win_amd64.whl (2.9 MB)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (3.17.3)
# Collecting termcolor~=1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting astunparse~=1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting absl-py~=0.10
#   Using cached absl_py-0.14.0-py3-none-any.whl (131 kB)
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting google-pasta~=0.2
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting keras-preprocessing~=1.1.2
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Collecting keras-nightly~=2.5.0.dev
#   Using cached keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (1.12.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (3.7.4.3)
# Requirement already satisfied: six~=1.15.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (0.36.2)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting tensorboard~=2.5
#   Using cached tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (52.0.0.post20210125)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.8.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2.26.0)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2.0.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.34.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jun\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jun\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\jun\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jun\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jun\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jun\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (3.1.1)
# Building wheels for collected packages: pykospacing
#   Building wheel for pykospacing (setup.py): started
#   Building wheel for pykospacing (setup.py): finished with status 'done'
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2255682 sha256=1c920c39caaa5a0695473041c8fcf4b4db39c77f2eeb6a0434b9740073931b26
#   Stored in directory: C:\Users\Jun\AppData\Local\Temp\pip-ephem-wheel-cache-vj4l35a0\wheels\79\a0\33\16f2cd03d21f76a663f5d69a0b96f0351335385349136fbd03
# Successfully built pykospacing
# Installing collected packages: markdown, grpcio, google-auth-oauthlib, absl-py, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, keras-nightly, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow, argparse, pykospacing
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to c:\users\jun\appdata\local\temp\pip-req-build-kydbisvk
# Collecting tensorflow==2.5.1
#   Downloading tensorflow-2.5.1-cp38-cp38-win_amd64.whl (422.6 MB)
# Collecting h5py==3.1.0
#   Using cached h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
# Collecting argparse>=1.4.0
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy>=1.17.5 in c:\users\jun\anaconda3\lib\site-packages (from h5py==3.1.0->pykospacing==0.5) (1.19.5)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (1.12.1)
# Collecting tensorboard~=2.5
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (3.7.4.3)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Collecting astunparse~=1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting google-pasta~=0.2
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: six~=1.15.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (1.15.0)
# Collecting grpcio~=1.34.0
#   Using cached grpcio-1.34.1-cp38-cp38-win_amd64.whl (2.9 MB)
# Collecting keras-nightly~=2.5.0.dev
#   Using cached keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
# Requirement already satisfied: wheel~=0.35 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (0.36.2)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.14.0-py3-none-any.whl (131 kB)
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (3.17.3)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting termcolor~=1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting keras-preprocessing~=1.1.2
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (52.0.0.post20210125)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2.26.0)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.8.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.34.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (0.6.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jun\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\jun\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jun\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jun\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jun\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jun\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (3.1.1)
# Building wheels for collected packages: pykospacing
#   Building wheel for pykospacing (setup.py): started
#   Building wheel for pykospacing (setup.py): finished with status 'done'
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2255682 sha256=f253968e98630977c081e55c556211279f5bdf913e879b0cfef7afa6ba50fb79
#   Stored in directory: C:\Users\Jun\AppData\Local\Temp\pip-ephem-wheel-cache-_uf4w5kp\wheels\79\a0\33\16f2cd03d21f76a663f5d69a0b96f0351335385349136fbd03
# Successfully built pykospacing
# Installing collected packages: markdown, grpcio, google-auth-oauthlib, absl-py, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, keras-nightly, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow, argparse, pykospacing
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
# Successfully installed absl-py-0.14.0 argparse-1.4.0 astunparse-1.6.3 flatbuffers-1.12 gast-0.4.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.34.1 h5py-3.1.0 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 markdown-3.3.4 opt-einsum-3.3.0 pykospacing-0.5 tensorboard-2.6.0 tensorflow-2.5.1 tensorflow-estimator-2.5.0 termcolor-1.1.0
#   Running command git clone -q https://github.com/haven-jeon/PyKoSpacing.git 'C:\Users\Jun\AppData\Local\Temp\pip-req-build-kydbisvk'
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Running command git clone -q https://github.com/haven-jeon/PyKoSpacing.git 'C:\Users\Jun\AppData\Local\Temp\pip-req-build-rogytxmg'
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to c:\users\jun\appdata\local\temp\pip-req-build-rogytxmg
# Collecting tensorflow==2.5.1
#   Using cached tensorflow-2.5.1-cp38-cp38-win_amd64.whl (422.6 MB)
# Requirement already satisfied: h5py==3.1.0 in c:\users\jun\anaconda3\lib\site-packages (from pykospacing==0.5) (3.1.0)
# Collecting argparse>=1.4.0
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy>=1.17.5 in c:\users\jun\anaconda3\lib\site-packages (from h5py==3.1.0->pykospacing==0.5) (1.19.5)
# Requirement already satisfied: wheel~=0.35 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (0.36.2)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (0.2.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (3.3.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (2.5.0.dev2021032900)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (3.17.3)
# Requirement already satisfied: gast==0.4.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (0.4.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (1.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (1.6.3)
# Requirement already satisfied: absl-py~=0.10 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (0.14.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (1.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (1.12.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (1.12)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (2.6.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (2.5.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (3.7.4.3)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (1.34.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.34.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2.26.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (52.0.0.post20210125)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (0.4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\jun\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jun\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jun\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jun\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jun\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.26.6)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jun\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (3.1.1)
# Building wheels for collected packages: pykospacing
#   Building wheel for pykospacing (setup.py): started
#   Building wheel for pykospacing (setup.py): finished with status 'done'
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2255682 sha256=55f599550e2e520af020b3ff40a6673de2ba8590a4253e9ef1420739a31ebf6f
#   Stored in directory: C:\Users\Jun\AppData\Local\Temp\pip-ephem-wheel-cache-z2xw3bi7\wheels\79\a0\33\16f2cd03d21f76a663f5d69a0b96f0351335385349136fbd03
# Successfully built pykospacing
# Installing collected packages: tensorflow, argparse, pykospacing
# Successfully installed argparse-1.4.0 pykospacing-0.5 tensorflow-2.5.1

# %%
# !python C:\hjun\git\talking-ai-bot\jupyter\py-hanspell-1.0\setup.py install

# %%
from nltk import sent_tokenize, word_tokenize
from konlpy.tag import Hannanum as hnm
from hanspell import spell_checker
from pykospacing import Spacing
import urllib.request
from soynlp import DoublespaceLineCorpus
from soynlp.word import WordExtractor
from konlpy.tag import Okt

def tokenize_text(input): # 단어 토큰화
    sentences = sent_tokenize(text=input)
    word_tokens = [word_tokenize(sentence) for sentence in sentences]
    return word_tokens


def spell_check(input): # 문장 체크
    spelled_sent = spell_checker.check(input)
    hanspell_sent = spelled_sent.checked
    return hanspell_sent
# Out:
#   Running command git clone -q https://github.com/haven-jeon/PyKoSpacing.git 'C:\Users\Jun\AppData\Local\Temp\pip-req-build-wfbvfsde'
# WARNING: Error parsing requirements for h5py: [Errno 2] No such file or directory: 'c:\\users\\jun\\anaconda3\\lib\\site-packages\\h5py-2.10.0.dist-info\\METADATA'
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to c:\users\jun\appdata\local\temp\pip-req-build-wfbvfsde
# Collecting tensorflow==2.5.1
#   Downloading tensorflow-2.5.1-cp38-cp38-win_amd64.whl (422.6 MB)
# Collecting h5py==3.1.0
#   Using cached h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
# Collecting argparse>=1.4.0
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy>=1.17.5 in c:\users\jun\anaconda3\lib\site-packages (from h5py==3.1.0->pykospacing==0.5) (1.19.5)
# Collecting grpcio~=1.34.0
#   Using cached grpcio-1.34.1-cp38-cp38-win_amd64.whl (2.9 MB)
# Requirement already satisfied: six~=1.15.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (1.15.0)
# Collecting google-pasta~=0.2
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting astunparse~=1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (1.12.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (3.7.4.3)
# Collecting absl-py~=0.10
#   Using cached absl_py-0.14.0-py3-none-any.whl (131 kB)
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting tensorboard~=2.5
#   Using cached tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
# Collecting termcolor~=1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting keras-preprocessing~=1.1.2
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: wheel~=0.35 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (0.36.2)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\jun\anaconda3\lib\site-packages (from tensorflow==2.5.1->pykospacing==0.5) (3.17.3)
# Collecting keras-nightly~=2.5.0.dev
#   Using cached keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2.26.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.8.0)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (52.0.0.post20210125)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2.0.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\jun\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.34.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jun\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jun\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\jun\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jun\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jun\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jun\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jun\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.1->pykospacing==0.5) (3.1.1)
# Building wheels for collected packages: pykospacing
#   Building wheel for pykospacing (setup.py): started
#   Building wheel for pykospacing (setup.py): finished with status 'done'
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2255682 sha256=beaf05e52d53bd55f531086e4d50d0904399d968ff4177045d4e4d8b7a3af394
#   Stored in directory: C:\Users\Jun\AppData\Local\Temp\pip-ephem-wheel-cache-tz9r4nyh\wheels\79\a0\33\16f2cd03d21f76a663f5d69a0b96f0351335385349136fbd03
# Successfully built pykospacing
# Installing collected packages: markdown, grpcio, google-auth-oauthlib, absl-py, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, keras-nightly, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow, argparse, pykospacing
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Can't uninstall 'h5py'. No files were found to uninstall.
# Successfully installed absl-py-0.14.0 argparse-1.4.0 astunparse-1.6.3 flatbuffers-1.12 gast-0.4.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.34.1 h5py-3.1.0 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 markdown-3.3.4 opt-einsum-3.3.0 pykospacing-0.5 tensorboard-2.6.0 tensorflow-2.5.1 tensorflow-estimator-2.5.0 termcolor-1.1.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-b95bc6fa9bf9> in <module>
#       1 from nltk import sent_tokenize, word_tokenize
#       2 from konlpy.tag import Hannanum as hnm
# ----> 3 from hanspell import spell_checker
#       4 from pykospacing import Spacing
#       5 import urllib.request
#
# ModuleNotFoundError: No module named 'hanspell'

# %%
from nltk import sent_tokenize, word_tokenize
from konlpy.tag import Hannanum as hnm
from hanspell import spell_checker
from pykospacing import Spacing
import urllib.request
from soynlp import DoublespaceLineCorpus
from soynlp.word import WordExtractor
from konlpy.tag import Okt

def tokenize_text(input): # 단어 토큰화
    sentences = sent_tokenize(text=input)
    word_tokens = [word_tokenize(sentence) for sentence in sentences]
    return word_tokens


def spell_check(input): # 문장 체크
    spelled_sent = spell_checker.check(input)
    hanspell_sent = spelled_sent.checked
    return hanspell_sent

# %%
import re
from nltk.stem import WordNetLemmatizer  # 어간 추출
from nltk.corpus import stopwords  # 불용어 배제
from nltk.tokenize import word_tokenize  # 토큰화 작업에 사용
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


class PreProcessing:
    def __init__(self):
        pass

    def text_pre_processing(input):
        # test
        return ""

    def text_cleaning(self, input, regex):  # input 값 정규식 전처리 ( 구두점 기준 전처리 )
        shortword = re.compile(regex)
        return shortword.sub('', input)

    def lemmatization(self, words):  # 어간 추출 ( 문장에서 토큰화 후 사용 )
        n = WordNetLemmatizer()
        return [n.lemmatize(w, 'v') for w in words]

    def stopword(self, input):  # 불용어 제거
        stop_words = set(stopwords.words('korean'))
        word_tokens = word_tokenize(input)

        result = list()
        for word in word_tokens:
            result.append(word)

        return result

    def padding(self, input):  # 최대 길이 만큼 문장의 길이를 맞추어 주는 함수
        padded = pad_sequences(PreProcessing().encoded(self, input))

        return

    def encoded(self, input):
        tokenizer = Tokenizer()
        tokenizer.fit_on_texts_to(input)
        encoded = tokenizer.texts_to_sequences(input)
        encoded = tokenizer.texts_to_sequences(input)

# %%
#!/usr/bin/env python
from setuptools import setup, find_packages

def install():
    required = []
    with open('requirements.txt','r',encoding = 'utf-16') as f:
        requirements = f.read().splitlines()
        for req in requirements:
            p = req.split('==')
            required.append(p[0])
    desc = ''
    setup(
        name='py-hanspell',
        version='1.0',
        description=desc,
        long_description=desc,
        author='SuHun Han',
        author_email='ssut@ssut.me',
        url='https://github.com/ssut/py-hanspell',
        classifiers = ['Development Status :: 5 - Production/Stable',
            'Intended Audience :: Education',
            'Intended Audience :: End Users/Desktop',
            'License :: Freeware',
            'Operating System :: POSIX',
            'Operating System :: Microsoft :: Windows',
            'Operating System :: MacOS :: MacOS X',
            'Topic :: Education',
            'Programming Language :: Python',
            'Programming Language :: Python :: 2.6',
            'Programming Language :: Python :: 2.7',
            'Programming Language :: Python :: 3.2',
            'Programming Language :: Python :: 3.3',
            'Programming Language :: Python :: 3.4'],
        packages=find_packages(),
        install_requires=required,
    )

if __name__ == "__main__":
    install()
